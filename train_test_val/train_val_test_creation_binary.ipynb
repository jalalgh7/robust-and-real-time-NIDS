# %%
import pickle 
import numpy as np
import pandas as pd
from skimage import io
import matplotlib.pyplot as plt
from PIL import Image
import cv2 
import os 
import random
import sys, os, glob, shutil
from random import shuffle

# %%
##benign = 0, 914343
##Slowloris = 1, 7414
##slowhttptest = 2, 5365
##HULK = 3, 689675
#GOLDENEYE = 4, 26932
#Heartbleed = 5, 17210
##ftp-patator = 6, 2541
##ssh-patator = 7, 2046
##webattack-brute = 8, 1418
##webattack-xss = 9
##webattack_sql =10
##infiltration = 11, 18220
##botnet=12, 3734
##port scan = 13, 114158
##ddos =14, 320748

# %%
##benign = 0
##Slowloris = 1
##slowhttptest = 2
##HULK = 3
#GOLDENEYE = 4
#Heartbleed = 5
##ftp-patator = 6
##ssh-patator = 7
##webattack-brute = 8
##infiltration = 11
##port scan = 13
##ddos =14

# %%
#grouped attacks

#benign = 0
#Dos (slowloris, slowhttptest, hulk, goldeneye, heartbleed) =1
#Bruteforce(ftp-patator, ssh-patator) = 2
#Webattack(webattack-bruteforce) = 3 Do not include 165 per image
#infiltration = 3
#botnet =4
#portscan =5
#ddos =6

# %%
os.chdir('..')

# %%
os.chdir('Friday/14.0/1')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jalal\\Desktop\\NIDS Datasets\\CICIDS2017\\image data 4\\Friday\\14.0\\1'

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
# Access all PNG files in directory
allfiles=os.listdir(os.getcwd())
imlist=[filename for filename in allfiles if  filename[-8:] in ["pkts.png"]]
print(len(imlist))
# Out:
# 167232

# %%
limit = len(imlist)-1089

# %%
#shuffle(imlist)

# %%
imlist = random.sample(imlist, limit)

# %%
len(imlist)
# Out:
# 166143

# %%
a = round(len(imlist)*0.70)

# %%
a
# Out:
# 770

# %%
train = imlist[0:a]

# %%
same_train = [i.strip('_15_pkts.png') for i in train]

# %%
b = round(len(imlist)*0.85)

# %%
val = imlist[a:b]

# %%
same_val = [i.strip('_15_pkts.png') for i in val]

# %%
c = len(imlist)

# %%
test = imlist[b:c]

# %%
same_test = [i.strip('_15_pkts.png') for i in test]

# %%
same_train
# Out:
# ['Strm_147487_im',
#  'Strm_209702_im',
#  'Strm_219415_im',
#  'Strm_233476_im',
#  'Strm_239215_im',
#  'Strm_223105_im',
#  'Strm_226456_im',
#  'Strm_213915_im',
#  'Strm_232605_im',
#  'Strm_180826_im',
#  'Strm_15491_im',
#  'Strm_203811_im',
#  'Strm_180518_im',
#  'Strm_212822_im',
#  'Strm_197384_im',
#  'Strm_163358_im',
#  'Strm_216419_im',
#  'Strm_220669_im',
#  'Strm_17309_im',
#  'Strm_231382_im',
#  'Strm_14186_im',
#  'Strm_157411_im',
#  'Strm_16768_im',
#  'Strm_232103_im',
#  'Strm_222098_im',
#  'Strm_210352_im',
#  'Strm_235231_im',
#  'Strm_216003_im',
#  'Strm_182791_im',
#  'Strm_159316_im',
#  'Strm_227509_im',
#  'Strm_1529_im',
#  'Strm_199942_im',
#  'Strm_174311_im',
#  'Strm_240937_im',
#  'Strm_9589_im',
#  'Strm_211856_im',
#  'Strm_217351_im',
#  'Strm_217126_im',
#  'Strm_2909_im',
#  'Strm_13449_im',
#  'Strm_217120_im',
#  'Strm_17292_im',
#  'Strm_233552_im',
#  'Strm_215999_im',
#  'Strm_184031_im',
#  'Strm_5857_im',
#  'Strm_182488_im',
# ...

# %%
test
# Out:
# ['Strm_163374_img_15_pkts.png',
#  'Strm_223851_img_15_pkts.png',
#  'Strm_174238_img_15_pkts.png',
#  'Strm_198772_img_15_pkts.png',
#  'Strm_243089_img_15_pkts.png',
#  'Strm_191945_img_15_pkts.png',
#  'Strm_236738_img_15_pkts.png',
#  'Strm_224184_img_15_pkts.png',
#  'Strm_230732_img_15_pkts.png',
#  'Strm_159576_img_15_pkts.png',
#  'Strm_239796_img_15_pkts.png',
#  'Strm_220827_img_15_pkts.png',
#  'Strm_214808_img_15_pkts.png',
#  'Strm_183607_img_15_pkts.png',
#  'Strm_229058_img_15_pkts.png',
#  'Strm_239788_img_15_pkts.png',
#  'Strm_236446_img_15_pkts.png',
#  'Strm_212390_img_15_pkts.png',
#  'Strm_8731_img_15_pkts.png',
#  'Strm_195133_img_15_pkts.png',
#  'Strm_148608_img_15_pkts.png',
#  'Strm_15758_img_15_pkts.png',
#  'Strm_236450_img_15_pkts.png',
#  'Strm_179615_img_15_pkts.png',
#  'Strm_210084_img_15_pkts.png',
#  'Strm_195072_img_15_pkts.png',
#  'Strm_215685_img_15_pkts.png',
#  'Strm_148323_img_15_pkts.png',
#  'Strm_156924_img_15_pkts.png',
# ...

# %%
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
os.chdir('..')

# %%
os.chdir('1')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jalal\\Desktop\\NIDS Datasets\\CICIDS2017\\image data 4\\Wednesday\\0.0\\1'

# %%
#(filename[:14] in same_train or filename[:13] in same_train or filename[:12] in same_train or filename[:11] in same_train)

# %%
# Access all PNG files in directory
allfiles=os.listdir(os.getcwd())
train=[filename for filename in allfiles if  (filename[:13] in same_train or filename[:14] in same_train or filename[:12] in same_train or filename[:11] in same_train or filename[:10] in same_train)]
print(len(train))
# Out:
# 770

# %%
# Access all PNG files in directory
allfiles=os.listdir(os.getcwd())
val=[filename for filename in allfiles if  (filename[:13] in same_val or filename[:14] in same_val or filename[:12] in same_val or filename[:11] in same_val or filename[:10] in same_val) ]
print(len(val))
# Out:
# 165

# %%
# Access all PNG files in directory
allfiles=os.listdir(os.getcwd())
test=[filename for filename in allfiles if  (filename[:13] in same_test or filename[:14] in same_test or filename[:12] in same_test or filename[:11] in same_test )]
print(len(test))
# Out:
# 165

# %%
test
# Out:
# ['Strm_1018_img_1_pkts.png',
#  'Strm_10489_img_1_pkts.png',
#  'Strm_1055_img_1_pkts.png',
#  'Strm_11360_img_1_pkts.png',
#  'Strm_11669_img_1_pkts.png',
#  'Strm_135860_img_1_pkts.png',
#  'Strm_1382_img_1_pkts.png',
#  'Strm_13879_img_1_pkts.png',
#  'Strm_14598_img_1_pkts.png',
#  'Strm_146122_img_1_pkts.png',
#  'Strm_147317_img_1_pkts.png',
#  'Strm_148323_img_1_pkts.png',
#  'Strm_148608_img_1_pkts.png',
#  'Strm_148624_img_1_pkts.png',
#  'Strm_149215_img_1_pkts.png',
#  'Strm_149412_img_1_pkts.png',
#  'Strm_1512_img_1_pkts.png',
#  'Strm_153078_img_1_pkts.png',
#  'Strm_153128_img_1_pkts.png',
#  'Strm_154587_img_1_pkts.png',
#  'Strm_156924_img_1_pkts.png',
#  'Strm_157408_img_1_pkts.png',
#  'Strm_15758_img_1_pkts.png',
#  'Strm_157838_img_1_pkts.png',
#  'Strm_15904_img_1_pkts.png',
#  'Strm_159202_img_1_pkts.png',
#  'Strm_15943_img_1_pkts.png',
#  'Strm_159576_img_1_pkts.png',
#  'Strm_159627_img_1_pkts.png',
#  'Strm_16000_img_1_pkts.png',
# ...

# %%
#########################################################################################

# %%
#list_of_random_images = random.sample(imlist, 100)

# %%
source_folder = r"C:\Users\Jalal\Desktop\NIDS Datasets\CICIDS2017\Image data 4\Wednesday\0.0\1\\"
destination_folder = r"C:\Users\Jalal\Desktop\NIDS Datasets\CICIDS2017\Image data 4\Binary-classification\train_binary\0\\"

files_to_move = train

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.copy(source, destination)
    #print('Moved:', file)

# %%
source_folder = r"C:\Users\Jalal\Desktop\NIDS Datasets\CICIDS2017\Image data 4\Wednesday\0.0\1\\"
destination_folder = r"C:\Users\Jalal\Desktop\NIDS Datasets\CICIDS2017\Image data 4\Binary-classification\val_binary\0\\"

files_to_move = val

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.copy(source, destination)
    #print('Moved:', file)

# %%
source_folder = r"C:\Users\Jalal\Desktop\NIDS Datasets\CICIDS2017\Image data 4\Wednesday\0.0\1\\"
destination_folder = r"C:\Users\Jalal\Desktop\NIDS Datasets\CICIDS2017\Image data 4\Binary-classification\test_binary1\0\\"

files_to_move = test

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.copy(source, destination)
    #print('Moved:', file)
